# %% [markdown]
# <a href="https://colab.research.google.com/github/masud770/AI-and-Machine-Learning-Practice-Examples/blob/main/linear_regration_practice_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("/content/placement.csv")
df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [1000 rows x 3 columns]

# %%
 df.isnull().sum()
# Out:
# cgpa                    0
# placement_exam_marks    0
# placed                  0
# dtype: int64

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
df.shape
# Out:
# (1000, 3)

# %%
x= df[['placement_exam_marks']]
y= df[['cgpa']]

# %%
x

# %%
y

# %%
plt.scatter(df['placement_exam_marks'],df['cgpa'])

# %%
plt.scatter(df['placement_exam_marks'],df['cgpa'], marker= '+', color='red')
plt.xlabel('placement_exam_marks')
plt.ylabel('CGPA')
plt.title('Placement')
# Out:
# Text(0.5, 1.0, 'Placement')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.25, random_state=1)

# %%
x_train
# Out:
#      placement_exam_marks
# 298                  48.0
# 160                  10.0
# 268                  21.0
# 658                   9.0
# 996                  65.0
# ..                    ...
# 767                  31.0
# 72                   19.0
# 908                  17.0
# 235                  52.0
# 37                    9.0
#
# [750 rows x 1 columns]

# %%
y_train
# Out:
#      cgpa
# 298  6.16
# 160  7.36
# 268  7.38
# 658  7.57
# 996  9.12
# ..    ...
# 767  7.33
# 72   7.90
# 908  6.06
# 235  7.20
# 37   8.51
#
# [750 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
re = LinearRegression()

# %%
re.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_test
# Out:
#      cgpa
# 507  6.77
# 818  5.52
# 452  6.59
# 368  7.09
# 242  5.99
# ..    ...
# 385  7.33
# 890  7.73
# 439  6.67
# 135  6.63
# 567  6.18
#
# [250 rows x 1 columns]

# %%
re.predict(x_test)

# %%
plt.scatter(df['placement_exam_marks'],df['cgpa'], marker= '+', color='red')
plt.xlabel('placement_exam_marks')
plt.ylabel('CGPA')
plt.title('Placement')
plt.plot(df.placement_exam_marks, re.predict(df[['placement_exam_marks']]))

# %%
re.predict([[90]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[6.92106726]])

# %%
re.coef_
# Out:
# array([[-0.00088459]])

# %%
re.intercept_
# Out:
# array([7.00068069])

# %%
y = -0.00088459*90+7.00068069
y
# Out:
# 6.92106759
