# %% [markdown]
# <a href="https://colab.research.google.com/github/masud770/AI-and-Machine-Learning-Practice-Examples/blob/main/Encoding_practice(22_9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/train_update.csv")
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 384    902727         B        13.28         13.72           85.79      541.8
# 385     90291         M        14.60         23.29           93.97      664.7
# 386    902975         B        12.21         14.09           78.78      462.0
# 387    902976         B        13.88         16.16           88.37      596.6
# 388    903011         B        11.27         15.50           73.38      392.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       389 non-null    int64
#  1   diagnosis                389 non-null    object
#  2   radius_mean              389 non-null    float64
#  3   texture_mean             389 non-null    float64
#  4   perimeter_mean           389 non-null    float64
#  5   area_mean                389 non-null    float64
#  6   smoothness_mean          389 non-null    float64
#  7   compactness_mean         389 non-null    float64
#  8   concavity_mean           389 non-null    float64
#  9   concave points_mean      389 non-null    float64
#  10  symmetry_mean            389 non-null    float64
#  11  fractal_dimension_mean   389 non-null    float64
#  12  radius_se                389 non-null    float64
#  13  texture_se               389 non-null    float64
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df['diagnosis'].value_counts()
# Out:
# B    219
# M    170
# Name: diagnosis, dtype: int64

# %%
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %% [markdown]
# LABEL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()

# %%
df['diagnosis'] = lb.fit_transform(df['diagnosis'])
df
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 384    902727          0        13.28         13.72           85.79
# 385     90291          1        14.60         23.29           93.97
# 386    902975          0        12.21         14.09           78.78
# 387    902976          0        13.88         16.16           88.37
# 388    903011          0        11.27         15.50           73.38
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %% [markdown]
# ORDINARY ENCODING

# %%
df2=pd.read_csv('/customer.csv')
df2
# Out:
#     age  gender   review education purchased
# 0    30  Female  Average    School        No
# 1    68  Female     Poor        UG        No
# 2    70  Female     Good        PG        No
# 3    72  Female     Good        PG        No
# 4    16  Female  Average        UG        No
# 5    31  Female  Average    School       Yes
# 6    18    Male     Good    School        No
# 7    60  Female     Poor    School       Yes
# 8    65  Female  Average        UG        No
# 9    74    Male     Good        UG       Yes
# 10   98  Female     Good        UG       Yes
# 11   74    Male     Good        UG       Yes
# 12   51    Male     Poor    School        No
# 13   57  Female  Average    School        No
# 14   15    Male     Poor        PG       Yes
# 15   75    Male     Poor        UG        No
# 16   59    Male     Poor        UG       Yes
# 17   22  Female     Poor        UG       Yes
# 18   19    Male     Good    School        No
# 19   97    Male     Poor        PG       Yes
# ...

# %%
df2.head(10)
# Out:
#    age  gender   review education purchased
# 0   30  Female  Average    School        No
# 1   68  Female     Poor        UG        No
# 2   70  Female     Good        PG        No
# 3   72  Female     Good        PG        No
# 4   16  Female  Average        UG        No
# 5   31  Female  Average    School       Yes
# 6   18    Male     Good    School        No
# 7   60  Female     Poor    School       Yes
# 8   65  Female  Average        UG        No
# 9   74    Male     Good        UG       Yes

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        50 non-null     int64
#  1   gender     50 non-null     object
#  2   review     50 non-null     object
#  3   education  50 non-null     object
#  4   purchased  50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
df2.isnull().sum().sum()
# Out:
# 0

# %%
df2[['review', 'education']].head()
# Out:
#     review education
# 0  Average    School
# 1     Poor        UG
# 2     Good        PG
# 3     Good        PG
# 4  Average        UG

# %%
df2['review'].unique()
# Out:
# array(['Average', 'Poor', 'Good'], dtype=object)

# %%
df2['education'].unique()
# Out:
# array(['School', 'UG', 'PG'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder(categories = [['Average','Poor','Good'],['School','UG','PG']])

# %%
df2[['review', 'education']]= oe.fit_transform(df2[['review', 'education']])

# %%
oe.categories_
# Out:
# [array(['Average', 'Poor', 'Good'], dtype=object),
#  array(['School', 'UG', 'PG'], dtype=object)]

# %%
df2[['review', 'education']]
# Out:
#     review  education
# 0      0.0        0.0
# 1      1.0        1.0
# 2      2.0        2.0
# 3      2.0        2.0
# 4      0.0        1.0
# 5      0.0        0.0
# 6      2.0        0.0
# 7      1.0        0.0
# 8      0.0        1.0
# 9      2.0        1.0
# 10     2.0        1.0
# 11     2.0        1.0
# 12     1.0        0.0
# 13     0.0        0.0
# 14     1.0        2.0
# 15     1.0        1.0
# 16     1.0        1.0
# 17     1.0        1.0
# 18     2.0        0.0
# 19     1.0        2.0
# 20     0.0        0.0
# 21     0.0        2.0
# 22     1.0        2.0
# 23     2.0        0.0
# 24     0.0        2.0
# 25     2.0        0.0
# 26     1.0        2.0
# 27     1.0        2.0
# 28     1.0        0.0
# 29     0.0        1.0
# 30     0.0        1.0
# 31     1.0        0.0
# 32     0.0        1.0
# 33     2.0        2.0
# 34     0.0        0.0
# 35     1.0        0.0
# 36     2.0        1.0
# 37     0.0        2.0
# 38     2.0        0.0
# 39     1.0        2.0
# ...

# %%
df2
# Out:
#     age  gender  review  education purchased
# 0    30  Female     0.0        0.0        No
# 1    68  Female     1.0        1.0        No
# 2    70  Female     2.0        2.0        No
# 3    72  Female     2.0        2.0        No
# 4    16  Female     0.0        1.0        No
# 5    31  Female     0.0        0.0       Yes
# 6    18    Male     2.0        0.0        No
# 7    60  Female     1.0        0.0       Yes
# 8    65  Female     0.0        1.0        No
# 9    74    Male     2.0        1.0       Yes
# 10   98  Female     2.0        1.0       Yes
# 11   74    Male     2.0        1.0       Yes
# 12   51    Male     1.0        0.0        No
# 13   57  Female     0.0        0.0        No
# 14   15    Male     1.0        2.0       Yes
# 15   75    Male     1.0        1.0        No
# 16   59    Male     1.0        1.0       Yes
# 17   22  Female     1.0        1.0       Yes
# 18   19    Male     2.0        0.0        No
# 19   97    Male     1.0        2.0       Yes
# ...

# %% [markdown]
# LABEL ENCODING

# %%
df3= pd.read_csv('/customer.csv')
df3
# Out:
#     age  gender   review education purchased
# 0    30  Female  Average    School        No
# 1    68  Female     Poor        UG        No
# 2    70  Female     Good        PG        No
# 3    72  Female     Good        PG        No
# 4    16  Female  Average        UG        No
# 5    31  Female  Average    School       Yes
# 6    18    Male     Good    School        No
# 7    60  Female     Poor    School       Yes
# 8    65  Female  Average        UG        No
# 9    74    Male     Good        UG       Yes
# 10   98  Female     Good        UG       Yes
# 11   74    Male     Good        UG       Yes
# 12   51    Male     Poor    School        No
# 13   57  Female  Average    School        No
# 14   15    Male     Poor        PG       Yes
# 15   75    Male     Poor        UG        No
# 16   59    Male     Poor        UG       Yes
# 17   22  Female     Poor        UG       Yes
# 18   19    Male     Good    School        No
# 19   97    Male     Poor        PG       Yes
# ...

# %%
df3.isnull().sum().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()

# %%
df2['purchased']= le.fit_transform(df2['purchased'])

# %%
df2
# Out:
#     age  gender  review  education  purchased
# 0    30  Female     0.0        0.0          0
# 1    68  Female     1.0        1.0          0
# 2    70  Female     2.0        2.0          0
# 3    72  Female     2.0        2.0          0
# 4    16  Female     0.0        1.0          0
# 5    31  Female     0.0        0.0          1
# 6    18    Male     2.0        0.0          0
# 7    60  Female     1.0        0.0          1
# 8    65  Female     0.0        1.0          0
# 9    74    Male     2.0        1.0          1
# 10   98  Female     2.0        1.0          1
# 11   74    Male     2.0        1.0          1
# 12   51    Male     1.0        0.0          0
# 13   57  Female     0.0        0.0          0
# 14   15    Male     1.0        2.0          1
# 15   75    Male     1.0        1.0          0
# 16   59    Male     1.0        1.0          1
# 17   22  Female     1.0        1.0          1
# 18   19    Male     2.0        0.0          0
# ...

# %%
le.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# ONE HOT ENCODING

# %%
df2['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df2['gender'].value_counts()
# Out:
# Female    29
# Male      21
# Name: gender, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
